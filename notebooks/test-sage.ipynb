# %%
var('x y')
solve(x^2 + y^2 == 1, x)
# Out:
# [x == -sqrt(-y^2 + 1), x == sqrt(-y^2 + 1)]

# %%
complex_plot(lambda z: 1/(1+z), (-5,5), (-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive
